# %% [markdown]
# #### Задача 1.
#
# Дано трехзначное число. Найдите сумму его цифр.

# %%
number=(int(input("введите число"))) #123
b = number // 10 % 10
a = number // 100
c = number % 10
d = a+b+c
print(d)
# Out:
# 6

# %% [markdown]
# #### Задача 2.
#
# Процентная ставка по вкладу составляет P процентов годовых, которые прибавляются к сумме вклада. Вклад составляет X рублей Y копеек. Определите размер вклада через год.
# Программа получает на вход целые числа P, X, Y и должна вывести два числа: величину вклада через год в рублях и копейках. Дробная часть копеек отбрасывается.

# %%
p = float(input('величина процентной ставки')) #10% (чиселки я для проверки себе пишу)
x = int(input('размер вклада (рубли)')) #1155
y = int(input('размер вклада (копейки)')) #65
v = x * 100 + y #размер вклада только в копейках
a = int(v + v / 100 * 10) / 100 
print(a)
# если нужно в формате n.рублей m.копеек, то
b = a * 100 % 100
a = int(a)
print(f'величина вклада через год составляет {a} рублей {b} копеек')
# Out:
# 1271.21
# величина вклада через год составляет 1271 рублей 21.0 копеек

# %% [markdown]
# #### Задача 3.
#
# В первый день спортсмен пробежал x километров, а затем он каждый день увеличивал пробег на 70% от предыдущего значения. По данному числу y определите номер дня, на который пробег спортсмена составит не менее y километров.
#
# На вход программа получает два числа x и y. Числа положительные, действительные, не превосходят 1000.
#
# Программа должна вывести единственное целое число.
#
# Для проверки:
#
# |Ввод|Вывод|
# |:-:|:-:|
# |10 30|4|

# %%
while True:
   x = float(input('количество километров в первый день'))
   y = float(input('введите количество километров, чтобы узнать, сколько потребуется дней'))
   if x >= 1000 or x < 1:
       x = float(input('количество километров в первый день (количество км не должно превышать 1000 и быть не меньше нуля)'))
   else:
    break 
   if y >= 1000 or y < 1:
      y = float(input('введите количество километров, чтобы узнать, сколько потребуется дней (количество км не должно превышать 1000 и быть не меньше нуля)'))
   else: 
    break
a = 1
while x < y:
    a = a + 1
    x = x / 100 * 170 
print(a)
# Out:
# 4

# %% [markdown]
# #### Задача 4.
#
# В первый день спортсмент пробежал x километров, а затем он каждый день увеличивал пробег на 70% от предыдущего значения.
#
# По данному числу y определите номер дня, на который суммарный пробег спортсмена составит не менее y километров.
#
# На вход программа получает два числа x и y. Числа положительные, действительные, не превосходят 1000.
#
# Программа должна вывести единственное целое число.
#
# Для проверки:
#
# |Ввод|Вывод|
# |:-:|:-:|
# |10 100|4|

# %%
while True:
   x = float(input('количество километров в первый день'))
   y = float(input('введите количество километров, чтобы узнать, сколько потребуется дней'))
   if x >= 1000 or x < 1:
       x = float(input('количество километров в первый день (количество км не должно превышать 1000 и быть не меньше нуля)'))
   else:
    break 
   if y >= 1000 or y < 1:
      y = float(input('введите количество километров, чтобы узнать, сколько потребуется дней (количество км не должно превышать 1000 и быть не меньше нуля)'))
   else: 
    break
a = 1 #количество дней
b = x # сумма км
while b < y:
    a = a + 1
    x = x /100 * 170
    b = b + x
print(a)
print(b) # включила в проверку сумму км, потому что сначала (с точно неправильным кодом) выходило тоже 4 дня, но сумма км была неправильная
# Out:
# 4
# 105.03

# %% [markdown]
# #### Задача 5.
#
# Числа Фибоначчи (простые). Вводится целое число: с помощью формулы выведите число Фибоначчи с этим номером.

# %%
n = int(input()) # 6
f0 = 0
f1 = 1 
k = 1
while n > k:
    fb = f0 + f1
    f0 = f1
    f1 = fb
    k = k + 1
if n == 1:
    fb = 1
if n == 0:
    fb = 0
    
print(fb)
# Out:
# 8

# %% [markdown]
# #### Задача 6.
#
# Напишите программу, которая на вход принимает число секунд и возвращает его в часах, минутах и секундах в формате HH:MM:SS.

# %%
s = int(input()) # 6252287
h = (s / 3600)
s = h - int(h)
h = int(h)
s = (s * 3600)
m = s / 60
s = m - int(m)
m = int(m)
s = int(s * 60)
print(f'{h}:{m}:{s}')
#s = h % 1
#выглядит странно, но вроде работает
# Out:
# 1736:44:47

# %% [markdown]
# Для чтения:
#
# 1. [М. Саммерфилд](https://drive.google.com/file/d/1VXoXN5Cl2GxfgYkuKFzVFRwltQnPGYol/view?usp=sharing). 2 глава, до строк.
# 2. [М. Лутц](https://drive.google.com/file/d/1oTnJq_jl7QEe1AQVBirJr2Oen_XQxS59/view?usp=sharing). 1 часть.
# 3. [Мануал по Github](https://github.com/rsuh-python/mag2022/blob/main/Github_Manual.pdf).
#
# Также можно дополнительно на Википедии почитать про машинный ноль, про хэш-функции и хэш-таблицы (это для общего развития).
